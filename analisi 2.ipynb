# %%
import pandas as pd

df_m=pd.read_csv("../../BW Python/melluso.csv")

# %%
df_m= df_m.replace("Décolleté", "Dècolletè")
df_m= df_m.replace("Infradita", "Infradito")
df_m= df_m.replace("Scarpa", "Sneakers")

# %%
df_l=pd.read_csv("../../BW Python/lumberjack.csv")
df_l.columns=["Nome","Modello", "Prezzo"]

# %%
df_l= df_l.replace("Scarpa", "Sneakers")
df_l = df_l.replace("Sneaker", "Sneakers")
df_l = df_l.replace("Green boat shoes", "Scarpe da barca")
df_l= df_l.replace("Sandali", "Sandalo")

# %%
prezzi_m=df_m.groupby("Modello")["Prezzo"].describe()

# %%
prezzi_m["Brand"] = "Melluso"

# %%
prezzi_l["Brand"] = "Lumberjack"

# %%
prezzi_l=df_l.groupby("Modello")["Prezzo"].describe()

# %%
prezzi_l = prezzi_l.loc[:"mean"].round(2)

# %%
prezzi_l["Brand"] = "Lumberjack"
prezzi_l
# Out:
#                       count   mean    std    min    25%    50%    75%    max  \
# Modello
# Sandalo                56.0  58.17  10.47  39.99  49.99  59.99  69.99  74.99
# Scarpe da barca        10.0  85.99   2.11  84.99  84.99  84.99  84.99  89.99
# Scarpe da ginnastica    7.0  46.42   8.02  39.99  39.99  39.99  54.99  54.99
# Slip on                 3.0  43.32   5.77  39.99  39.99  39.99  44.99  49.99
# Sneakers               85.0  60.99  17.56  34.99  39.99  59.99  69.99  89.99
#
#                            Brand
# Modello
# Sandalo               Lumberjack
# Scarpe da barca       Lumberjack
# Scarpe da ginnastica  Lumberjack
# Slip on               Lumberjack
# Sneakers              Lumberjack

# %%
prezzi_m = prezzi_m.loc[:"mean"].round(2)
prezzi_m
# Out:
#              count    mean    std   min     25%    50%    75%    max    Brand
# Modello
# Ciabatta      34.0   96.19  25.33  59.9   82.40   89.9  119.0  139.9  Melluso
# Dècolletè     76.0  149.36  14.61  89.9  139.90  149.9  159.9  189.9  Melluso
# Espadrillas    4.0   79.90   0.00  79.9   79.90   79.9   79.9   79.9  Melluso
# Infradito      8.0   89.90   0.00  89.9   89.90   89.9   89.9   89.9  Melluso
# Mocassino     18.0  122.63  21.35  89.9  104.90  119.9  129.9  159.9  Melluso
# Sandalo      123.0  121.19  26.42  79.9   89.90  129.0  139.9  169.9  Melluso
# Sneakers      36.0  137.41  25.87  89.9  118.68  149.9  159.9  169.9  Melluso

# %%
Confronto= pd.concat([prezzi_m, prezzi_l])

# %%
Confronto
# Out:
#                       count    mean    std    min     25%     50%     75%  \
# Modello
# Ciabatta               34.0   96.19  25.33  59.90   82.40   89.90  119.00
# Dècolletè              76.0  149.36  14.61  89.90  139.90  149.90  159.90
# Espadrillas             4.0   79.90   0.00  79.90   79.90   79.90   79.90
# Infradito               8.0   89.90   0.00  89.90   89.90   89.90   89.90
# Mocassino              18.0  122.63  21.35  89.90  104.90  119.90  129.90
# Sandalo               123.0  121.19  26.42  79.90   89.90  129.00  139.90
# Sneakers               36.0  137.41  25.87  89.90  118.68  149.90  159.90
# Sandalo                56.0   58.17  10.47  39.99   49.99   59.99   69.99
# Scarpe da barca        10.0   85.99   2.11  84.99   84.99   84.99   84.99
# Scarpe da ginnastica    7.0   46.42   8.02  39.99   39.99   39.99   54.99
# Slip on                 3.0   43.32   5.77  39.99   39.99   39.99   44.99
# Sneakers               85.0   60.99  17.56  34.99   39.99   59.99   69.99
#
#                          max       Brand
# Modello
# Ciabatta              139.90     Melluso
# Dècolletè             189.90     Melluso
# Espadrillas            79.90     Melluso
# Infradito              89.90     Melluso
# Mocassino             159.90     Melluso
# Sandalo               169.90     Melluso
# Sneakers              169.90     Melluso
# Sandalo                74.99  Lumberjack
# Scarpe da barca        89.99  Lumberjack
# Scarpe da ginnastica   54.99  Lumberjack
# Slip on                49.99  Lumberjack
# Sneakers               89.99  Lumberjack

# %%
Confronto.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 Confronto.reset_index(inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'reset_index'

# %%
Confronto

# %%
import seaborn as sns

# %%
Confronto.plot(x="Brand", y="index", kind="hist")
